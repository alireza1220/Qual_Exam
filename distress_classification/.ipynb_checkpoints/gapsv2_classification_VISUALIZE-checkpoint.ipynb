# %%
# %%bash
# ls saved_models
# Out:
# classification_5_11.pickle
# classification_5_37.pickle
# classification_5_84.pickle
# run110_61.pickle
# run2_27.pickle
# run2_48.pickle
# run2_56.pickle
# run2_5.pickle
# run4_29.pickle
# run4_71.pickle
# run_watch_22.pickle
# tf3_23_58.pickle
# tf3_73.pickle
# Untitled.ipynb

# %%
RUN_NAME = 'classification_5'

# %%
import pickle
PATH_SAVE = '/home/ali/my_project/gaps/saved_models/' + RUN_NAME+ '_'
pickle_in = open(PATH_SAVE + str(84) + '.pickle',"rb")
history = pickle.load(pickle_in)

# %%
# Plot training & validation loss values
import matplotlib.pyplot as plt
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(history['accuracy'], label='accuracy')
plt.plot(history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
