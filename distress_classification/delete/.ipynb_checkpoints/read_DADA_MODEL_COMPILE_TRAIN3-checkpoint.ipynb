# %%
from importlib.machinery import SourceFileLoader
MODULENAME = "loadgaps"
MODULEPATH = "/home/ali/my_project/large_files/gaps/loadgaps.py"
lgaps = SourceFileLoader(MODULENAME, MODULEPATH).load_module()

v2_tr_patch_num = 7 # upto 25
v2_va_patch_num = 2# upto 5
v2_te_patch_num = 2# upto 5
issue_input='ZEB_50k'
patch_size_input = 128

x_train, y_train, x_valid, y_valid, x_test, y_test = lgaps.loadv2(
                                                patch_size_input= patch_size_input,# [64, 96, 128, 160, 192, 224, 256]
                                                issue_input     =issue_input,  # ['NORMvsDISTRESS_50k', 'ZEB_50k']
                                                v2_tr_patch_num = v2_tr_patch_num, # upto 154
                                                v2_va_patch_num = v2_va_patch_num, # upto 7
                                                v2_te_patch_num = v2_te_patch_num  # upto 26
                                                )
# Out:
# loading 1 chunk  out of 7 of training in v2 gaps
# loading 2 chunk  out of 7 of training in v2 gaps
# loading 3 chunk  out of 7 of training in v2 gaps
# loading 4 chunk  out of 7 of training in v2 gaps
# loading 5 chunk  out of 7 of training in v2 gaps
# loading 6 chunk  out of 7 of training in v2 gaps
# loading 7 chunk  out of 7 of training in v2 gaps
# loading 1 chunk  out of 2 of valid in v2 gaps
# loading 2 chunk  out of 2 of valid in v2 gaps
# loading 1 chunk  out of 2 of test in v2 gaps
# loading 2 chunk  out of 2 of test in v2 gaps

# %%
from tensorflow.keras import utils
if issue_input == 'ZEB_50k':
    num_classes = 6
elif issue_input == 'NORMvsDISTRESS_50k':
    num_classes = 2
else:
    print('enter valid issue input')

y_train = utils.to_categorical(y_train, num_classes)
y_valid = utils.to_categorical(y_valid, num_classes)
y_test = utils.to_categorical(y_test, num_classes)

# %%
shape_input = x_train[0,:,:,:].shape
print(f'input shape  : {shape_input}')
print(f'train num is : {y_train.shape[0]}')
print(f'valid num is : {y_valid.shape[0]}')
print(f'test  num is : {y_test.shape[0]}')
# Out:
# input shape  : (1, 128, 128)
# train num is : 50000
# valid num is : 10000
# test  num is : 10000

# %%
import readmodel
#model = readmodel.modelchoose( 'model_4', (256, 256, 3), 6)
model = readmodel.modelchoose( 'model_5', shape_input, num_classes)
model.summary()
# Out:
# add first channel
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 126, 126)      320
# _________________________________________________________________
# activation (Activation)      (None, 32, 126, 126)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 124, 32)       36320
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 124, 32)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 62, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 62, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 62, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 62, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 60, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 60, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 30, 64)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 30, 64)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 11520)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               5898752
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 3078
# _________________________________________________________________
# activation_5 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 5,993,894
# Trainable params: 5,993,894
# Non-trainable params: 0
# _________________________________________________________________

# %%
# initiate RMSprop optimizer
#from tensorflow import keras
#opt = keras.optimizers.RMSprop(learning_rate=0.01,momentum=0.7, decay=1e-6)
if num_classes == 2:
    loss = 'binary_crossentropy'
if num_classes == 6:
    loss = 'categorical_crossentropy'
    
print(loss)

#model.compile( loss = loss, # loss='categorical_crossentropy',
#              optimizer=opt,
#              metrics=['accuracy'])


from tensorflow.keras.optimizers import SGD
opt = SGD(lr=0.01)
model.compile(loss = loss, optimizer = opt,  metrics=['accuracy'] )
# Out:
# categorical_crossentropy

# %%
epochs = 200 # 200
batch_size = 256
#num_classes = y_train_binary.shape[1]
history = model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_valid, y_valid),
              shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/200
# 50000/50000 [==============================] - 42s 831us/sample - loss: 1.2547 - accuracy: 0.5945 - val_loss: 1.1808 - val_accuracy: 0.6000
# Epoch 2/200
# 50000/50000 [==============================] - 37s 738us/sample - loss: 1.1894 - accuracy: 0.6000 - val_loss: 1.1526 - val_accuracy: 0.6000
# Epoch 3/200
# 50000/50000 [==============================] - 39s 771us/sample - loss: 1.1313 - accuracy: 0.6092 - val_loss: 1.1796 - val_accuracy: 0.5939
# Epoch 4/200
# 50000/50000 [==============================] - 39s 771us/sample - loss: 1.0395 - accuracy: 0.6519 - val_loss: 1.1573 - val_accuracy: 0.6024
# Epoch 5/200
# 50000/50000 [==============================] - 39s 772us/sample - loss: 0.9774 - accuracy: 0.6741 - val_loss: 1.0679 - val_accuracy: 0.5998
# Epoch 6/200
# 50000/50000 [==============================] - 39s 773us/sample - loss: 0.9477 - accuracy: 0.6838 - val_loss: 1.1112 - val_accuracy: 0.5959
# Epoch 7/200
# 50000/50000 [==============================] - 39s 774us/sample - loss: 0.9168 - accuracy: 0.6943 - val_loss: 1.1916 - val_accuracy: 0.5914
# Epoch 8/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.8913 - accuracy: 0.7024 - val_loss: 1.0425 - val_accuracy: 0.6050
# Epoch 9/200
# 50000/50000 [==============================] - 39s 781us/sample - loss: 0.8682 - accuracy: 0.7087 - val_loss: 1.0937 - val_accuracy: 0.5998
# Epoch 10/200
# 50000/50000 [==============================] - 39s 774us/sample - loss: 0.8551 - accuracy: 0.7113 - val_loss: 1.1248 - val_accuracy: 0.5772
# Epoch 11/200
# 50000/50000 [==============================] - 39s 774us/sample - loss: 0.8408 - accuracy: 0.7156 - val_loss: 1.0471 - val_accuracy: 0.6131
# Epoch 12/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.8293 - accuracy: 0.7193 - val_loss: 1.0426 - val_accuracy: 0.6119
# Epoch 13/200
# 50000/50000 [==============================] - 39s 774us/sample - loss: 0.8162 - accuracy: 0.7225 - val_loss: 1.0761 - val_accuracy: 0.6101
# Epoch 14/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.8083 - accuracy: 0.7264 - val_loss: 1.0713 - val_accuracy: 0.6124
# Epoch 15/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.7989 - accuracy: 0.7292 - val_loss: 1.0534 - val_accuracy: 0.6194
# Epoch 16/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.7885 - accuracy: 0.7320 - val_loss: 1.0476 - val_accuracy: 0.6138
# Epoch 17/200
# 50000/50000 [==============================] - 39s 774us/sample - loss: 0.7815 - accuracy: 0.7356 - val_loss: 1.0215 - val_accuracy: 0.6238
# Epoch 18/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.7712 - accuracy: 0.7395 - val_loss: 1.0604 - val_accuracy: 0.6247
# Epoch 19/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.7612 - accuracy: 0.7428 - val_loss: 1.0584 - val_accuracy: 0.6131
# Epoch 20/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.7579 - accuracy: 0.7445 - val_loss: 1.1631 - val_accuracy: 0.6058
# Epoch 21/200
# 50000/50000 [==============================] - 39s 777us/sample - loss: 0.7471 - accuracy: 0.7485 - val_loss: 1.0298 - val_accuracy: 0.6267
# Epoch 22/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.7397 - accuracy: 0.7510 - val_loss: 1.0284 - val_accuracy: 0.6175
# Epoch 23/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.7350 - accuracy: 0.7526 - val_loss: 1.0643 - val_accuracy: 0.6147
# Epoch 24/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.7265 - accuracy: 0.7555 - val_loss: 1.0843 - val_accuracy: 0.6113
# Epoch 25/200
# 50000/50000 [==============================] - 39s 777us/sample - loss: 0.7189 - accuracy: 0.7585 - val_loss: 1.0195 - val_accuracy: 0.6371
# Epoch 26/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.7134 - accuracy: 0.7601 - val_loss: 0.9760 - val_accuracy: 0.6457
# Epoch 27/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.7064 - accuracy: 0.7623 - val_loss: 1.0932 - val_accuracy: 0.6215
# Epoch 28/200
# 50000/50000 [==============================] - 39s 777us/sample - loss: 0.7007 - accuracy: 0.7640 - val_loss: 1.0879 - val_accuracy: 0.6227
# Epoch 29/200
# 50000/50000 [==============================] - 39s 778us/sample - loss: 0.6947 - accuracy: 0.7649 - val_loss: 1.0683 - val_accuracy: 0.6393
# Epoch 30/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.6868 - accuracy: 0.7671 - val_loss: 1.0048 - val_accuracy: 0.6444
# Epoch 31/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.6837 - accuracy: 0.7694 - val_loss: 0.9953 - val_accuracy: 0.6436
# Epoch 32/200
# 50000/50000 [==============================] - 39s 774us/sample - loss: 0.6777 - accuracy: 0.7697 - val_loss: 1.0150 - val_accuracy: 0.6306
# Epoch 33/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.6740 - accuracy: 0.7720 - val_loss: 1.0031 - val_accuracy: 0.6475
# Epoch 34/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.6645 - accuracy: 0.7743 - val_loss: 0.9665 - val_accuracy: 0.6523
# Epoch 35/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.6613 - accuracy: 0.7756 - val_loss: 1.0272 - val_accuracy: 0.6466
# Epoch 36/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.6579 - accuracy: 0.7756 - val_loss: 1.0367 - val_accuracy: 0.6314
# Epoch 37/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.6564 - accuracy: 0.7769 - val_loss: 1.2270 - val_accuracy: 0.5761
# Epoch 38/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.6479 - accuracy: 0.7792 - val_loss: 1.0500 - val_accuracy: 0.6286
# Epoch 39/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.6439 - accuracy: 0.7799 - val_loss: 0.9958 - val_accuracy: 0.6502
# Epoch 40/200
# 50000/50000 [==============================] - 39s 777us/sample - loss: 0.6386 - accuracy: 0.7811 - val_loss: 1.0014 - val_accuracy: 0.6507
# Epoch 41/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.6354 - accuracy: 0.7828 - val_loss: 1.0191 - val_accuracy: 0.6491
# Epoch 42/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.6335 - accuracy: 0.7834 - val_loss: 1.0413 - val_accuracy: 0.6695
# Epoch 43/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.6268 - accuracy: 0.7868 - val_loss: 0.9967 - val_accuracy: 0.6535
# Epoch 44/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.6235 - accuracy: 0.7878 - val_loss: 1.0910 - val_accuracy: 0.6099
# Epoch 45/200
# 50000/50000 [==============================] - 39s 777us/sample - loss: 0.6182 - accuracy: 0.7885 - val_loss: 0.9552 - val_accuracy: 0.6687
# Epoch 46/200
# 50000/50000 [==============================] - 39s 777us/sample - loss: 0.6123 - accuracy: 0.7920 - val_loss: 1.0152 - val_accuracy: 0.6520
# Epoch 47/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.6101 - accuracy: 0.7903 - val_loss: 0.9412 - val_accuracy: 0.6720
# Epoch 48/200
# 50000/50000 [==============================] - 39s 777us/sample - loss: 0.6030 - accuracy: 0.7915 - val_loss: 0.9878 - val_accuracy: 0.6675
# Epoch 49/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.6043 - accuracy: 0.7922 - val_loss: 1.0180 - val_accuracy: 0.6503
# Epoch 50/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.5987 - accuracy: 0.7961 - val_loss: 0.9751 - val_accuracy: 0.6657
# Epoch 51/200
# 50000/50000 [==============================] - 39s 774us/sample - loss: 0.5938 - accuracy: 0.7976 - val_loss: 0.9700 - val_accuracy: 0.6648
# Epoch 52/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.5918 - accuracy: 0.7959 - val_loss: 1.1974 - val_accuracy: 0.5763
# Epoch 53/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.5858 - accuracy: 0.7998 - val_loss: 1.0668 - val_accuracy: 0.6485
# Epoch 54/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.5842 - accuracy: 0.7988 - val_loss: 1.0517 - val_accuracy: 0.6303
# Epoch 55/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.5775 - accuracy: 0.8011 - val_loss: 1.0289 - val_accuracy: 0.6465
# Epoch 56/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.5735 - accuracy: 0.8018 - val_loss: 0.9906 - val_accuracy: 0.6616
# Epoch 57/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.5700 - accuracy: 0.8038 - val_loss: 1.0011 - val_accuracy: 0.6532
# Epoch 58/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.5668 - accuracy: 0.8027 - val_loss: 1.0939 - val_accuracy: 0.6081
# Epoch 59/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.5636 - accuracy: 0.8048 - val_loss: 0.9670 - val_accuracy: 0.6698
# Epoch 60/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.5595 - accuracy: 0.8071 - val_loss: 0.9822 - val_accuracy: 0.6859
# Epoch 61/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.5556 - accuracy: 0.8094 - val_loss: 1.0625 - val_accuracy: 0.6234
# Epoch 62/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.5542 - accuracy: 0.8095 - val_loss: 0.9946 - val_accuracy: 0.6729
# Epoch 63/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.5486 - accuracy: 0.8099 - val_loss: 0.9566 - val_accuracy: 0.6767
# Epoch 64/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.5471 - accuracy: 0.8112 - val_loss: 1.0821 - val_accuracy: 0.6359
# Epoch 65/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.5431 - accuracy: 0.8124 - val_loss: 0.9868 - val_accuracy: 0.6692
# Epoch 66/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.5377 - accuracy: 0.8144 - val_loss: 1.0357 - val_accuracy: 0.6545
# Epoch 67/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.5380 - accuracy: 0.8132 - val_loss: 1.0538 - val_accuracy: 0.6578
# Epoch 68/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.5345 - accuracy: 0.8140 - val_loss: 0.9999 - val_accuracy: 0.6570
# Epoch 69/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.5306 - accuracy: 0.8158 - val_loss: 0.9849 - val_accuracy: 0.6802
# Epoch 70/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.5271 - accuracy: 0.8186 - val_loss: 0.9909 - val_accuracy: 0.6700
# Epoch 71/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.5242 - accuracy: 0.8176 - val_loss: 1.0554 - val_accuracy: 0.6438
# Epoch 72/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.5215 - accuracy: 0.8182 - val_loss: 0.9612 - val_accuracy: 0.6727
# Epoch 73/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.5198 - accuracy: 0.8203 - val_loss: 0.9951 - val_accuracy: 0.6664
# Epoch 74/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.5172 - accuracy: 0.8212 - val_loss: 0.9657 - val_accuracy: 0.6794
# Epoch 75/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.5108 - accuracy: 0.8235 - val_loss: 1.0414 - val_accuracy: 0.6324
# Epoch 76/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.5090 - accuracy: 0.8241 - val_loss: 1.0352 - val_accuracy: 0.6423
# Epoch 77/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.5066 - accuracy: 0.8261 - val_loss: 0.9818 - val_accuracy: 0.6728
# Epoch 78/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.5047 - accuracy: 0.8245 - val_loss: 1.0458 - val_accuracy: 0.6515
# Epoch 79/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.5021 - accuracy: 0.8255 - val_loss: 0.9748 - val_accuracy: 0.6796
# Epoch 80/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.4992 - accuracy: 0.8254 - val_loss: 1.0171 - val_accuracy: 0.6430
# Epoch 81/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.4957 - accuracy: 0.8291 - val_loss: 1.0101 - val_accuracy: 0.6552
# Epoch 82/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.4918 - accuracy: 0.8285 - val_loss: 1.0182 - val_accuracy: 0.6866
# Epoch 83/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.4929 - accuracy: 0.8279 - val_loss: 1.0045 - val_accuracy: 0.6736
# Epoch 84/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.4887 - accuracy: 0.8296 - val_loss: 1.0859 - val_accuracy: 0.6338
# Epoch 85/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.4860 - accuracy: 0.8306 - val_loss: 1.0518 - val_accuracy: 0.6477
# Epoch 86/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.4872 - accuracy: 0.8310 - val_loss: 1.1621 - val_accuracy: 0.6014
# Epoch 87/200
# 50000/50000 [==============================] - 37s 741us/sample - loss: 0.4827 - accuracy: 0.8316 - val_loss: 1.0629 - val_accuracy: 0.6828
# Epoch 88/200
# 50000/50000 [==============================] - 39s 787us/sample - loss: 0.4815 - accuracy: 0.8328 - val_loss: 0.9527 - val_accuracy: 0.6862
# Epoch 89/200
# 50000/50000 [==============================] - 39s 784us/sample - loss: 0.4760 - accuracy: 0.8349 - val_loss: 1.0487 - val_accuracy: 0.6365
# Epoch 90/200
# 50000/50000 [==============================] - 39s 785us/sample - loss: 0.4773 - accuracy: 0.8334 - val_loss: 1.0044 - val_accuracy: 0.6828
# Epoch 91/200
# 50000/50000 [==============================] - 39s 778us/sample - loss: 0.4721 - accuracy: 0.8350 - val_loss: 1.1130 - val_accuracy: 0.6408
# Epoch 92/200
# 50000/50000 [==============================] - 39s 779us/sample - loss: 0.4712 - accuracy: 0.8348 - val_loss: 1.0697 - val_accuracy: 0.6671
# Epoch 93/200
# 50000/50000 [==============================] - 39s 778us/sample - loss: 0.4685 - accuracy: 0.8384 - val_loss: 1.0940 - val_accuracy: 0.6199
# Epoch 94/200
# 50000/50000 [==============================] - 39s 779us/sample - loss: 0.4621 - accuracy: 0.8403 - val_loss: 1.1594 - val_accuracy: 0.5856
# Epoch 95/200
# 50000/50000 [==============================] - 39s 780us/sample - loss: 0.4615 - accuracy: 0.8385 - val_loss: 1.0250 - val_accuracy: 0.6675
# Epoch 96/200
# 50000/50000 [==============================] - 39s 778us/sample - loss: 0.4604 - accuracy: 0.8399 - val_loss: 1.0198 - val_accuracy: 0.6625
# Epoch 97/200
# 50000/50000 [==============================] - 39s 778us/sample - loss: 0.4539 - accuracy: 0.8420 - val_loss: 0.9994 - val_accuracy: 0.6778
# Epoch 98/200
# 50000/50000 [==============================] - 39s 779us/sample - loss: 0.4554 - accuracy: 0.8411 - val_loss: 1.0454 - val_accuracy: 0.6649
# Epoch 99/200
# 50000/50000 [==============================] - 39s 780us/sample - loss: 0.4504 - accuracy: 0.8444 - val_loss: 1.0512 - val_accuracy: 0.6735
# Epoch 100/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.4495 - accuracy: 0.8434 - val_loss: 1.0180 - val_accuracy: 0.6668
# Epoch 101/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.4470 - accuracy: 0.8451 - val_loss: 1.0461 - val_accuracy: 0.6941
# Epoch 102/200
# 50000/50000 [==============================] - 39s 778us/sample - loss: 0.4443 - accuracy: 0.8450 - val_loss: 1.0203 - val_accuracy: 0.6907
# Epoch 103/200
# 50000/50000 [==============================] - 39s 774us/sample - loss: 0.4414 - accuracy: 0.8460 - val_loss: 0.9729 - val_accuracy: 0.6807
# Epoch 104/200
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.4403 - accuracy: 0.8466 - val_loss: 1.1647 - val_accuracy: 0.5876
# Epoch 105/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.4385 - accuracy: 0.8482 - val_loss: 1.0301 - val_accuracy: 0.6619
# Epoch 106/200
# 50000/50000 [==============================] - 39s 777us/sample - loss: 0.4379 - accuracy: 0.8480 - val_loss: 1.0956 - val_accuracy: 0.6490
# Epoch 107/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.4366 - accuracy: 0.8478 - val_loss: 1.0472 - val_accuracy: 0.6676
# Epoch 108/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.4320 - accuracy: 0.8504 - val_loss: 1.0264 - val_accuracy: 0.6967
# Epoch 109/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.4309 - accuracy: 0.8501 - val_loss: 1.1576 - val_accuracy: 0.6284
# Epoch 110/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.4264 - accuracy: 0.8509 - val_loss: 1.0286 - val_accuracy: 0.6782
# Epoch 111/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.4250 - accuracy: 0.8525 - val_loss: 1.0631 - val_accuracy: 0.6565
# Epoch 112/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.4205 - accuracy: 0.8534 - val_loss: 1.0793 - val_accuracy: 0.6726
# Epoch 113/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.4214 - accuracy: 0.8532 - val_loss: 1.0294 - val_accuracy: 0.7070
# Epoch 114/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.4153 - accuracy: 0.8546 - val_loss: 1.0804 - val_accuracy: 0.6234
# Epoch 115/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.4146 - accuracy: 0.8569 - val_loss: 1.1305 - val_accuracy: 0.6715
# Epoch 116/200
# 50000/50000 [==============================] - 37s 736us/sample - loss: 0.4143 - accuracy: 0.8571 - val_loss: 1.0739 - val_accuracy: 0.6494
# Epoch 117/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.4109 - accuracy: 0.8566 - val_loss: 1.0513 - val_accuracy: 0.6836
# Epoch 118/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.4094 - accuracy: 0.8567 - val_loss: 1.1122 - val_accuracy: 0.6808
# Epoch 119/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.4060 - accuracy: 0.8586 - val_loss: 1.0654 - val_accuracy: 0.6857
# Epoch 120/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.4047 - accuracy: 0.8584 - val_loss: 1.1163 - val_accuracy: 0.6435
# Epoch 121/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.4040 - accuracy: 0.8594 - val_loss: 1.0625 - val_accuracy: 0.6603
# Epoch 122/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.4017 - accuracy: 0.8599 - val_loss: 1.0332 - val_accuracy: 0.6898
# Epoch 123/200
# 50000/50000 [==============================] - 37s 736us/sample - loss: 0.3980 - accuracy: 0.8602 - val_loss: 1.0854 - val_accuracy: 0.6405
# Epoch 124/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.4002 - accuracy: 0.8603 - val_loss: 1.0994 - val_accuracy: 0.6908
# Epoch 125/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3983 - accuracy: 0.8604 - val_loss: 1.0887 - val_accuracy: 0.6860
# Epoch 126/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3929 - accuracy: 0.8626 - val_loss: 1.0422 - val_accuracy: 0.6909
# Epoch 127/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.3914 - accuracy: 0.8626 - val_loss: 1.1380 - val_accuracy: 0.6770
# Epoch 128/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3898 - accuracy: 0.8668 - val_loss: 1.0689 - val_accuracy: 0.6641
# Epoch 129/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3879 - accuracy: 0.8635 - val_loss: 1.0574 - val_accuracy: 0.6781
# Epoch 130/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3836 - accuracy: 0.8662 - val_loss: 1.1005 - val_accuracy: 0.6776
# Epoch 131/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3817 - accuracy: 0.8667 - val_loss: 1.1401 - val_accuracy: 0.6756
# Epoch 132/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3827 - accuracy: 0.8678 - val_loss: 1.0430 - val_accuracy: 0.7012
# Epoch 133/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3751 - accuracy: 0.8703 - val_loss: 1.0896 - val_accuracy: 0.6613
# Epoch 134/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.3781 - accuracy: 0.8687 - val_loss: 1.1129 - val_accuracy: 0.6915
# Epoch 135/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3751 - accuracy: 0.8676 - val_loss: 1.1051 - val_accuracy: 0.6611
# Epoch 136/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3731 - accuracy: 0.8704 - val_loss: 1.1082 - val_accuracy: 0.6734
# Epoch 137/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3711 - accuracy: 0.8709 - val_loss: 1.1434 - val_accuracy: 0.6946
# Epoch 138/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3668 - accuracy: 0.8716 - val_loss: 1.0867 - val_accuracy: 0.6922
# Epoch 139/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.3647 - accuracy: 0.8714 - val_loss: 1.1372 - val_accuracy: 0.6615
# Epoch 140/200
# 50000/50000 [==============================] - 37s 736us/sample - loss: 0.3662 - accuracy: 0.8724 - val_loss: 1.1855 - val_accuracy: 0.6041
# Epoch 141/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3598 - accuracy: 0.8734 - val_loss: 1.0573 - val_accuracy: 0.6919
# Epoch 142/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3604 - accuracy: 0.8722 - val_loss: 1.1152 - val_accuracy: 0.6612
# Epoch 143/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.3595 - accuracy: 0.8750 - val_loss: 1.2349 - val_accuracy: 0.6043
# Epoch 144/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3581 - accuracy: 0.8752 - val_loss: 1.1987 - val_accuracy: 0.6852
# Epoch 145/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3554 - accuracy: 0.8749 - val_loss: 1.1006 - val_accuracy: 0.6675
# Epoch 146/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3533 - accuracy: 0.8753 - val_loss: 1.1486 - val_accuracy: 0.6612
# Epoch 147/200
# 50000/50000 [==============================] - 37s 736us/sample - loss: 0.3482 - accuracy: 0.8788 - val_loss: 1.1729 - val_accuracy: 0.6564
# Epoch 148/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.3481 - accuracy: 0.8783 - val_loss: 1.1220 - val_accuracy: 0.6821
# Epoch 149/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.3495 - accuracy: 0.8771 - val_loss: 1.2070 - val_accuracy: 0.6635
# Epoch 150/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3444 - accuracy: 0.8810 - val_loss: 1.1895 - val_accuracy: 0.6738
# Epoch 151/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3439 - accuracy: 0.8798 - val_loss: 1.2136 - val_accuracy: 0.6089
# Epoch 152/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3362 - accuracy: 0.8821 - val_loss: 1.1723 - val_accuracy: 0.6754
# Epoch 153/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.3398 - accuracy: 0.8791 - val_loss: 1.2321 - val_accuracy: 0.6426
# Epoch 154/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3355 - accuracy: 0.8809 - val_loss: 1.2611 - val_accuracy: 0.6779
# Epoch 155/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3361 - accuracy: 0.8813 - val_loss: 1.1870 - val_accuracy: 0.6861
# Epoch 156/200
# 50000/50000 [==============================] - 37s 736us/sample - loss: 0.3320 - accuracy: 0.8817 - val_loss: 1.1662 - val_accuracy: 0.6799
# Epoch 157/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3301 - accuracy: 0.8846 - val_loss: 1.1937 - val_accuracy: 0.6480
# Epoch 158/200
# 50000/50000 [==============================] - 37s 736us/sample - loss: 0.3286 - accuracy: 0.8840 - val_loss: 1.1647 - val_accuracy: 0.6630
# Epoch 159/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.3308 - accuracy: 0.8827 - val_loss: 1.2739 - val_accuracy: 0.6765
# Epoch 160/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.3266 - accuracy: 0.8848 - val_loss: 1.3346 - val_accuracy: 0.6881
# Epoch 161/200
# 50000/50000 [==============================] - 37s 736us/sample - loss: 0.3179 - accuracy: 0.8883 - val_loss: 1.1413 - val_accuracy: 0.6540
# Epoch 162/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3218 - accuracy: 0.8871 - val_loss: 1.1845 - val_accuracy: 0.6721
# Epoch 163/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.3181 - accuracy: 0.8890 - val_loss: 1.1909 - val_accuracy: 0.6845
# Epoch 164/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3202 - accuracy: 0.8867 - val_loss: 1.1406 - val_accuracy: 0.6916
# Epoch 165/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3144 - accuracy: 0.8899 - val_loss: 1.2230 - val_accuracy: 0.6700
# Epoch 166/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3153 - accuracy: 0.8887 - val_loss: 1.2783 - val_accuracy: 0.6871
# Epoch 167/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3121 - accuracy: 0.8899 - val_loss: 1.1632 - val_accuracy: 0.6921
# Epoch 168/200
# 50000/50000 [==============================] - 37s 732us/sample - loss: 0.3062 - accuracy: 0.8894 - val_loss: 1.2395 - val_accuracy: 0.6509
# Epoch 169/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3105 - accuracy: 0.8900 - val_loss: 1.2925 - val_accuracy: 0.6836
# Epoch 170/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3061 - accuracy: 0.8915 - val_loss: 1.2284 - val_accuracy: 0.6993
# Epoch 171/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.3024 - accuracy: 0.8934 - val_loss: 1.1579 - val_accuracy: 0.7002
# Epoch 172/200
# 50000/50000 [==============================] - 37s 735us/sample - loss: 0.3011 - accuracy: 0.8930 - val_loss: 1.2122 - val_accuracy: 0.6803
# Epoch 173/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.2984 - accuracy: 0.8957 - val_loss: 1.2481 - val_accuracy: 0.6472
# Epoch 174/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.2989 - accuracy: 0.8950 - val_loss: 1.2281 - val_accuracy: 0.6933
# Epoch 175/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.2964 - accuracy: 0.8948 - val_loss: 1.2956 - val_accuracy: 0.7019
# Epoch 176/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.2952 - accuracy: 0.8965 - val_loss: 1.5372 - val_accuracy: 0.6917
# Epoch 177/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.2934 - accuracy: 0.8955 - val_loss: 1.1925 - val_accuracy: 0.6971
# Epoch 178/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.2925 - accuracy: 0.8971 - val_loss: 1.2127 - val_accuracy: 0.6606
# Epoch 179/200
# 50000/50000 [==============================] - 37s 733us/sample - loss: 0.2874 - accuracy: 0.8976 - val_loss: 1.2316 - val_accuracy: 0.6544
# Epoch 180/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.2862 - accuracy: 0.8988 - val_loss: 1.2940 - val_accuracy: 0.6248
# Epoch 181/200
# 50000/50000 [==============================] - 37s 734us/sample - loss: 0.2860 - accuracy: 0.8981 - val_loss: 1.2610 - val_accuracy: 0.6860
# Epoch 182/200
# 50000/50000 [==============================] - 37s 739us/sample - loss: 0.2889 - accuracy: 0.8983 - val_loss: 1.2982 - val_accuracy: 0.6804
# Epoch 183/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.2814 - accuracy: 0.8991 - val_loss: 1.2708 - val_accuracy: 0.6981
# Epoch 184/200
# 50000/50000 [==============================] - 39s 783us/sample - loss: 0.2821 - accuracy: 0.8998 - val_loss: 1.2422 - val_accuracy: 0.6666
# Epoch 185/200
# 50000/50000 [==============================] - 39s 780us/sample - loss: 0.2780 - accuracy: 0.9014 - val_loss: 1.2322 - val_accuracy: 0.6558
# Epoch 186/200
# 50000/50000 [==============================] - 40s 799us/sample - loss: 0.2748 - accuracy: 0.9021 - val_loss: 1.2890 - val_accuracy: 0.6897
# Epoch 187/200
# 50000/50000 [==============================] - 39s 780us/sample - loss: 0.2774 - accuracy: 0.9002 - val_loss: 1.4099 - val_accuracy: 0.6518
# Epoch 188/200
# 50000/50000 [==============================] - 39s 787us/sample - loss: 0.2728 - accuracy: 0.9040 - val_loss: 1.2674 - val_accuracy: 0.7002
# Epoch 189/200
# 50000/50000 [==============================] - 39s 778us/sample - loss: 0.2772 - accuracy: 0.9017 - val_loss: 1.2222 - val_accuracy: 0.6725
# Epoch 190/200
# 50000/50000 [==============================] - 39s 777us/sample - loss: 0.2682 - accuracy: 0.9044 - val_loss: 1.3393 - val_accuracy: 0.6852
# Epoch 191/200
# 50000/50000 [==============================] - 39s 778us/sample - loss: 0.2660 - accuracy: 0.9071 - val_loss: 1.2726 - val_accuracy: 0.6519
# Epoch 192/200
# 50000/50000 [==============================] - 39s 784us/sample - loss: 0.2682 - accuracy: 0.9055 - val_loss: 1.3553 - val_accuracy: 0.6403
# Epoch 193/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.2623 - accuracy: 0.9059 - val_loss: 1.2233 - val_accuracy: 0.7005
# Epoch 194/200
# 50000/50000 [==============================] - 39s 777us/sample - loss: 0.2647 - accuracy: 0.9059 - val_loss: 1.2954 - val_accuracy: 0.6781
# Epoch 195/200
# 50000/50000 [==============================] - 39s 782us/sample - loss: 0.2621 - accuracy: 0.9053 - val_loss: 1.3055 - val_accuracy: 0.6863
# Epoch 196/200
# 50000/50000 [==============================] - 39s 776us/sample - loss: 0.2590 - accuracy: 0.9062 - val_loss: 1.4120 - val_accuracy: 0.6782
# Epoch 197/200
# 50000/50000 [==============================] - 37s 745us/sample - loss: 0.2576 - accuracy: 0.9078 - val_loss: 1.3519 - val_accuracy: 0.6827
# Epoch 198/200
# 50000/50000 [==============================] - 37s 744us/sample - loss: 0.2570 - accuracy: 0.9090 - val_loss: 1.4414 - val_accuracy: 0.6570
# Epoch 199/200
# 50000/50000 [==============================] - 37s 743us/sample - loss: 0.2528 - accuracy: 0.9101 - val_loss: 1.3324 - val_accuracy: 0.6717
# Epoch 200/200
# 50000/50000 [==============================] - 37s 745us/sample - loss: 0.2497 - accuracy: 0.9099 - val_loss: 1.3591 - val_accuracy: 0.6666

# %%
scores = model.evaluate(x_test, y_test, verbose=2)
# Out:
# 10000/1 - 3s - loss: 1.5237 - accuracy: 0.6995

# %%
# Plot training & validation loss values
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
save_name  = 'run2'

dict_save = {}
dict_save['history'] = history.history
dict_save['model'] = model

# %%
import pickle
from random import random
Rand = str(int(100* random()))

PATH_SAVE = '/home/ali/my_project/gaps/saved_models/'
pickle_out = open(PATH_SAVE + save_name+'_'+ Rand + '.pickle',"wb")
pickle.dump(history.history, pickle_out)
pickle_out.close()
print('history and model are saved')
# Out:
# history and model are saved

# %%
# %%bash
# cd saved_models
# ls
# Out:
# model_1_epochs_40_batchsize_20.h5
# model_1_epochs_5_batchsize_50.h5
# run2_23.pickle
# run2.pickle
# Untitled.ipynb

# %%
print(Rand)
# Out:
# 28

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(6, 6))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(64):
    ax = fig.add_subplot(8, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(x_test[i, 0, :, :], cmap=plt.cm.binary, interpolation='nearest')
    # label the image with the target value
#    ax.text(10, 120, str(0))
